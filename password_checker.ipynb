# %% [markdown]
# <a href="https://colab.research.google.com/github/yasaswini-vls/beginner---python/blob/main/password_checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("LOGIN")
tr_loginid = "Yasaswini@16"
tr_pwd = "#2Tacobell"
user_loginid = input("Enter loginid")
user_pwd = input("Enter password")
attempt = 1

while tr_loginid != user_loginid and tr_pwd != user_pwd and attempt <=3:
    print("try again")
    print("you have ",3-attempt,"attempts left")
    user_loginid = input("Enter loginid")
    user_pwd = input("Enter password")
    attempt = attempt+1
if tr_loginid == user_loginid and tr_pwd == user_pwd:
  print("SUCCESS")
else:
  print('LOCKED')
# Out:
# LOGIN
# Enter loginidcat
# Enter passworddog
# try again
# you have  2 attempts left
# Enter loginidcat
# Enter passworddog
# try again
# you have  1 attempts left
# Enter loginidcat
# Enter passworddog
# try again
# you have  0 attempts left
# Enter loginidcat
# Enter passworddog
# LOCKED
