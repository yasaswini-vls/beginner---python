# %% [markdown]
# <a href="https://colab.research.google.com/github/yasaswini-vls/beginner---python/blob/main/largest_and_smallest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("enter your number"))
y=str(x)
m=max(list(y))
print("the largest digit is", str(m))
n=min(list(y))
print("the smallest digit is", str(n))
# Out:
# enter your number3483393880
# the largest digit is 9
# the smallest digit is 0
