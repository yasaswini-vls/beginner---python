# %% [markdown]
# <a href="https://colab.research.google.com/github/yasaswini-vls/beginner---python/blob/main/fibonacci.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("enter number"))
i=0
j=1
count = 3
print (i,j)
while count <= x:
  k=i+j
  print(k)
  i=j
  j=k
  count=count+1
# Out:
# enter number5
# 0 1
# 1
# 2
# 3
