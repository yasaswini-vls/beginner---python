# %% [markdown]
# <a href="https://colab.research.google.com/github/yasaswini-vls/beginner---python/blob/main/Check_if_number_is_prime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
z=int(input("Enter number"))
prime = True
for i in range(2,z):
  if z%i == 0:
     prime = False

if prime:
  print("prime")
else:
  print("not prime")
# Out:
# Enter number6
# not prime
